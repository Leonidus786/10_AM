# %% [markdown]
# ## Functions -- A block of code written to perform a particular task.
#
# ### In order to run it you need to call it.

# %%
def Sum(a, b):
    return a+b

# %%
Sum(1, 2)
# Out:
# 3

# %%
Sum("Abhishek ", "Upadhayay")
# Out:
# 'Abhishek Upadhayay'

# %% [markdown]
# ### Function Names
# Function names follow the same rules as variable names in Python:
#
# 1. A function name must start with a letter or underscore
# 2. A function name can only contain letters, numbers, and underscores
# 3. Function names are case-sensitive (myFunction and myfunction are different)

# %%
def multiply(m,n):
    return m*n

# %%
multiply(2,3)
# Out:
# 6

# %%
def my_function():
  pass

# %% [markdown]
# A parameter is the variable listed inside the parentheses in the function definition.
#
# An argument is the actual value that is sent to the function when it is called.

# %%
# Sum(3) # this will produce TypeError
