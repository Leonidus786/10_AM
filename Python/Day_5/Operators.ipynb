# %% [markdown]
# ## Operators :- Operators are used to perform operations on variables and values.
#
# 1. Arithmetic Operators
# 2. Comparison
# 3. Logical Operatrs
# 4. Bitwise Operators
# 5. Identity operators
# 6. Membership Operators
# 7. Assignment operators

# %%
# Arithmetic Operators -- Addition, Subtraction, Multiplication, Divison, Modulo(remainder), Floor divison, Exponentiation


a = 30
b = 6

# %%
a + b
# Out:
# 36

# %%
a - b
# Out:
# 24

# %%
a * b
# Out:
# 180

# %%
a / b  # whenever you divide things in python you alwas end up with getting a float.
# Out:
# 5.0

# %%
a % b # Modulo -- % -- Remainder
# Out:
# 0

# %%
a // b # Floor divison -- You will get quotient without decimals
# Out:
# 5

# %%
79 / 3
# Out:
# 26.333333333333332

# %%
79 % 3
# Out:
# 1

# %%
79 // 3
# Out:
# 26

# %%
a ** b # Exponentiation
# Out:
# 729000000

# %%
2 ** 4
# Out:
# 16

# %%
print(a)
print(b)
# Out:
# 30
# 6

# %% [markdown]
# ## Comparison Operators == Comparison operators are used to compare two values:

# %%
# Equality check -- ==

a == b
# Out:
# False

# %%
# Not equal to -- !=

a != b
# Out:
# True

# %%
# >	Greater than

a > b
# Out:
# True

# %%
# <	Less than

a < b
# Out:
# False

# %%
# >=	Greater than or equal to
a >= b
# Out:
# True

# %%
# <=	Less than or equal to

b <= a
# Out:
# True

# %%
a <= b
# Out:
# False
