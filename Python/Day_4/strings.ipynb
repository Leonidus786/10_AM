# %%
Name = "Aakash & Atul"

# %%
print(type(Name))
# Out:
# <class 'str'>

# %%
# indexing

Name[0]
# Out:
# 'A'

# %%
Name[1]
# Out:
# 'a'

# %%
Name[-1]
# Out:
# 'l'

# %%
# slicing
Name[0:]
# Out:
# 'Aakash & Atul'

# %%
Name[0:6]
# Out:
# 'Aakash'

# %%
Name[0:4]
# Out:
# 'Aaka'

# %%
Name
# Out:
# 'Aakash & Atul'

# %%
Name[9:]
# Out:
# 'Atul'

# %%
Name_1 = "Abhishek"

# %%
Name_1[::-1]
# Out:
# 'kehsihbA'

# %% [markdown]
# # Slicing --- [Start : Stop : Step]
#
# start is included in your output and stop is excluded in your output.
# Step == this number of character should be escaped.

# %%
Name_1[0::2]
# Out:
# 'Ahse'

# %%
Name[:]
# Out:
# 'Aakash & Atul'

# %%
Name_1
# Out:
# 'Abhishek'

# %%
Name_1.upper()
# Out:
# 'ABHISHEK'

# %%
Name_1.lower()
# Out:
# 'abhishek'

# %%
a = "  Hello, World!    "

# %%
a
# Out:
# '  Hello, World!    '

# %%
a.strip()
# Out:
# 'Hello, World!'

# %%
Name_2 = "aakash"

# %%
Name_2.replace('a','j')
# Out:
# 'jjkjsh'

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
a = "Hello, World!"
print(a.split(","))
# Out:
# ['Hello', ' World!']

# %%
a = "Abhishek"

b = "Upadhayay"

# %%
a
# Out:
# 'Abhishek'

# %%
b
# Out:
# 'Upadhayay'

# %%
# Concatenation == Adding two strings together.
c = a+' '+b

# %%
c
# Out:
# 'Abhishek Upadhayay'

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 age = 36
#       2 #This will produce an error:
# ----> 3 txt = "My name is John, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am " + str(age)
print(txt)
# Out:
# My name is John, I am 36

# %% [markdown]
# ## Numeric Datatypes : -
#
# 1. Integer -- int()
#
# 2. Float -- float()
#
# 3. Complex -- complex()

# %%
a = 2
b = 5.6
c = 2 + 3j # complex -- real(2) + imaginary(3j)

d = "dog"

# %%
## Type conversion --- Casting 

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>

# %%
e = float(a)
e
# Out:
# 2.0

# %%
f = int(b)
f
# Out:
# 5

# %%
c
# Out:
# (2+3j)

# %%
# g = int(c)
# g = float(c)
# tHE above two lines will produce error.

# %%
a
# Out:
# 2

# %%
h = complex(a)
h
# Out:
# (2+0j)

# %%
b
# Out:
# 5.6

# %%
i = complex(b)
i
# Out:
# (5.6+0j)

# %%
j = str(a)
j
# Out:
# '2'

# %%
k = str(b)
k
# Out:
# '5.6'

# %%
d
# Out:
# 'dog'

# %%
l = int(d)
l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 l = int(d)
#       2 l
#
# ValueError: invalid literal for int() with base 10: 'dog'

# %%
m = "2345678"

# %%
type(m)
# Out:
# str

# %%
n = int(m)

# %%
n
# Out:
# 2345678

# %%
o = float(m)
o
# Out:
# 2345678.0
