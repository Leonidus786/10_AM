# %% [markdown]
# ## A set is a collection which is unordered, unchangeable*, and unindexed.
#
# ### Set items are unchangeable, but you can remove items and add new items.

# %%
set_1 = {1, 2.5, 3+2j, "Amit", True, False}

# %%
print(type(set_1))
# Out:
# <class 'set'>

# %%
# do not allow duplicate values.

print(set_1)
# Out:
# {False, 1, 2.5, (3+2j), 'Amit'}

# %%
thisset = {"apple", "banana", "cherry", "apple", "banana", "cherry"}

print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
# The values True and 1 are considered the same value in sets, and are treated as duplicates.

set_2 = {" ", 0, 1, True, False}

# %%
print(set_2)
# Out:
# {0, 1, ' '}

# %%
set_2 = {" ",  True, False, 1}
print(set_2)
# Out:
# {False, True, ' '}

# %%
set_1
# Out:
# {(3+2j), 1, 2.5, 'Amit', False}

# %%
print(len(set_1))
# Out:
# 5

# %%
thisset = set(("apple", "banana", "cherry"))  # note the double round-brackets
print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
for i in set_2:
    print(i)
# Out:
# False
# True

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'apple', 'cherry', 'banana', 'orange'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'banana', 'pineapple', 'apple', 'cherry', 'mango', 'papaya'}

# %%
list_1 = ["Amit", "Abhishek", "Aditya", "Nitish"]

# %%
thisset.update(list_1)
print(thisset)
# Out:
# {'banana', 'Aditya', 'papaya', 'cherry', 'Nitish', 'Amit', 'apple', 'Abhishek', 'pineapple', 'mango'}

# %%
thisset.remove("banana")

print(thisset)
# Out:
# {'Aditya', 'papaya', 'cherry', 'Nitish', 'Amit', 'apple', 'Abhishek', 'pineapple', 'mango'}

# %%
# thisset.remove("banana")

# %%
thisset = {"apple", "banana", "cherry"}

thisset.discard("banana")

print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
thisset.discard("banana")

# %% [markdown]
# - The union() and update() methods joins all items from both sets.
#
# - The intersection() method keeps ONLY the duplicates.
#
# - The difference() method keeps the items from the first set that are not in the other set(s).
#
# - The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {'c', 1, 'b', 2, 3, 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

# | - standing slash
set3 = set1 | set2
print(set3)
# Out:
# {'c', 1, 'b', 2, 3, 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {1, 2, 'b', 3, 'John', 'apple', 'a', 'c', 'bananas', 'Elena', 'cherry'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1 | set2 | set3 | set4
print(myset)
# Out:
# {1, 2, 'b', 3, 'John', 'apple', 'a', 'c', 'bananas', 'Elena', 'cherry'}

# %%
x = {"a", "b", "c"}
y = (1, 2, 3)

z = x.union(y)
print(z)


#  The  | operator only allows you to join sets with sets, and not with other data types like you can with the  union() method.
# Out:
# {1, 2, 'b', 3, 'a', 'c'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)
# Out:
# {'c', 1, 'b', 2, 3, 'a'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %%
set1 = {0, "apple", 1,  "banana",  "cherry"}
set2 = {False, "google", 1, "apple", 2, True}

set3 = set1.intersection(set2)

print(set3)
# Out:
# {False, 1, 'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3)
# Out:
# {'cherry', 'banana'}
